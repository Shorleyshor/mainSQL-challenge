# %%
# import dependencies
import pandas as pd
import pprint
import psycopg2
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# SQLAlchemyfrom sqlalchemy import create_engine
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:@localhost:5432/mainSQL-challenge')
connection = engine.connect()

# %%
employees = pd.read_sql('select * from employees', connection, parse_dates=['birth_date','hire_date'])
employees.head()
# Out:
#    emp_no title_id birth_date  first_name  last_name sex  hire_date
# 0  473302    s0001 1953-07-25    Hideyuki   Zallocco   M 1990-04-28
# 1  475053    e0002 1954-11-18       Byong  Delgrande   F 1991-09-07
# 2   57444    e0002 1958-01-30       Berry       Babb   F 1992-03-21
# 3  421786    s0001 1957-09-28       Xiong   Verhoeff   M 1987-11-26
# 4  282238    e0003 1952-10-28  Abdelkader    Baumann   F 1991-01-18

# %%
dept_manager = pd.read_sql('select * from dept_manager', connection)
dept_manager.head()
# Out:
#   dept_no  emp_no
# 0    d001  110022
# 1    d001  110039
# 2    d002  110085
# 3    d002  110114
# 4    d003  110183

# %%
salaries = pd.read_sql('select * from salaries', connection)
salaries.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
titles = pd.read_sql('select * from titles', connection)
titles.head()
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer

# %%
# merge salaries with employee 
employee_salaries = employees.merge(salaries, on='emp_no')
employee_salaries.head()
# Out:
#    emp_no title_id birth_date  first_name  last_name sex  hire_date  salary
# 0  473302    s0001 1953-07-25    Hideyuki   Zallocco   M 1990-04-28   40000
# 1  475053    e0002 1954-11-18       Byong  Delgrande   F 1991-09-07   53422
# 2   57444    e0002 1958-01-30       Berry       Babb   F 1992-03-21   48973
# 3  421786    s0001 1957-09-28       Xiong   Verhoeff   M 1987-11-26   40000
# 4  282238    e0003 1952-10-28  Abdelkader    Baumann   F 1991-01-18   40000

# %%
employee_title = employee_salaries.merge(titles, on='title_id')
employee_title
# Out:
#         emp_no title_id birth_date  first_name   last_name sex  hire_date  \
# 0       473302    s0001 1953-07-25    Hideyuki    Zallocco   M 1990-04-28
# 1       421786    s0001 1957-09-28       Xiong    Verhoeff   M 1987-11-26
# 2       273487    s0001 1957-04-14   Christoph     Parfitt   M 1991-06-28
# 3       246449    s0001 1958-03-23       Subbu  Bultermann   F 1988-03-25
# 4        48085    s0001 1964-01-19  Venkatesan        Gilg   M 1993-06-28
# ...        ...      ...        ...         ...         ...  ..        ...
# 300019  111400    m0001 1959-11-09        Arie     Staelin   M 1985-01-01
# 300020  111133    m0001 1955-03-16       Hauke       Zhang   M 1986-12-30
# 300021  110085    m0001 1959-10-28        Ebru       Alpin   M 1985-01-01
# 300022  110386    m0001 1953-10-04        Shem      Kieras   M 1988-10-14
# 300023  111784    m0001 1956-06-14       Marjo  Giarratana   F 1988-02-12
#
#         salary    title
# 0        40000    Staff
# 1        40000    Staff
# 2        56087    Staff
# 3        87084    Staff
# 4        63016    Staff
# ...        ...      ...
# 300019   72446  Manager
# 300020   71148  Manager
# 300021   60026  Manager
# 300022   40000  Manager
# 300023   40000  Manager
#
# [300024 rows x 9 columns]

# %%
# create a dataframe of "emp_no", "title", "salary"
employee_df = employee_title[['emp_no','title','salary']]
employee_df
# Out:
#         emp_no    title  salary
# 0       473302    Staff   40000
# 1       421786    Staff   40000
# 2       273487    Staff   56087
# 3       246449    Staff   87084
# 4        48085    Staff   63016
# ...        ...      ...     ...
# 300019  111400  Manager   72446
# 300020  111133  Manager   71148
# 300021  110085  Manager   60026
# 300022  110386  Manager   40000
# 300023  111784  Manager   40000
#
# [300024 rows x 3 columns]

# %%
# group by title and show the first instances
employee_group =employee_title.groupby('title')
employee_group.first()
# Out:
#                     emp_no title_id birth_date  first_name  last_name sex  \
# title
# Assistant Engineer  252000    e0001 1952-12-03    Zhonghui   Gyimothy   F
# Engineer            475053    e0002 1954-11-18       Byong  Delgrande   F
# Manager             111877    m0001 1962-10-18     Xiaobin   Spinelli   F
# Senior Engineer     282238    e0003 1952-10-28  Abdelkader    Baumann   F
# Senior Staff        461591    s0002 1964-11-17      Xudong   Samarati   M
# Staff               473302    s0001 1953-07-25    Hideyuki   Zallocco   M
# Technique Leader     17934    e0004 1963-07-12    Bilhanan   Wuwongse   M
#
#                     hire_date  salary
# title
# Assistant Engineer 1989-03-02   40000
# Engineer           1991-09-07   53422
# Manager            1991-08-17   53846
# Senior Engineer    1991-01-18   40000
# Senior Staff       1985-11-13   40000
# Staff              1990-04-28   40000
# Technique Leader   1993-10-06   48795

# %%
# plot histogram of the most common salary ranges for employees
employee_title.hist(column="salary")

# set a title for the chart
plt.title ("Hstogram of the Most Common Salary Ranges")
plt.xlabel("Salary Ranges")
plt.ylabel("Number of Employees")
plt.savefig("img/histogram.png")
plt.show()

# %%
ls
# Out:
# EmployeeSQL/                           answer_query.sql
# README.md                              img.histogram.png
# Screenshot 2022-08-07 at 17.39.18.png  imghistogram.png
# Untitled.ipynb                         tablesquery.sql

# %%
cd img./
# Out:
# [Errno 2] No such file or directory: 'img./'
# /Users/darop/Documents/mainSQL-challenge
